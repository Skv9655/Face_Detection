# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import dlib

# %%
image = cv2.imread('C:\\Users\\skv96\\Downloads\\PRJ Face Detection-20240102T164837Z-001\\PRJ Face Detection\\Data Set\\people1.jpg')
image
# Out:
# array([[[ 91, 103, 107],
#         [102, 114, 118],
#         [ 94, 106, 110],
#         ...,
#         [187, 192, 193],
#         [186, 191, 192],
#         [185, 190, 191]],
#
#        [[ 93, 105, 109],
#         [ 97, 109, 113],
#         [ 95, 110, 113],
#         ...,
#         [187, 192, 193],
#         [186, 191, 192],
#         [185, 190, 191]],
#
#        [[ 98, 110, 114],
#         [ 98, 110, 114],
#         [102, 117, 120],
#         ...,
#         [186, 191, 192],
#         [185, 190, 191],
#         [184, 189, 190]],
#
#        ...,
#
#        [[ 48,  43,  40],
#         [ 46,  41,  38],
#         [ 44,  39,  36],
#         ...,
#         [251, 248, 244],
#         [252, 247, 244],
#         [251, 246, 243]],
#
#        [[ 55,  49,  44],
#         [ 53,  47,  42],
#         [ 49,  42,  39],
#         ...,
#         [252, 247, 244],
#         [252, 247, 244],
#         [252, 247, 244]],
#
#        [[ 56,  50,  45],
#         [ 54,  48,  43],
#         [ 50,  44,  39],
# ...

# %%
image.shape
# Out:
# (1280, 1920, 3)

# %%
plt.imshow(image)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
cv2.imshow('',image)
cv2.waitKey(20000)
# cv2.destroyAllWindows() simply destroys all the windows we created.
cv2.destroyAllWindows()

# %%
image = cv2.resize(image, (1000,600))
image.shape
# Out:
# (600, 1000, 3)

# %%
cv2.imshow('',image)
cv2.waitKey(20000)
cv2.destroyAllWindows()

# %%
plt.imshow(image)
plt.show()

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow('',image_gray)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
image_gray.shape
# Out:
# (600, 1000)

# %%
display (image_gray.shape)
# Out:
# (600, 1000)

# %%
face_detector = cv2.CascadeClassifier('C:\\Users\\skv96\\Downloads\\PRJ Face Detection-20240102T164837Z-001\\PRJ Face Detection\\Cascades\\haarcascade_frontalface_default.xml')
if face_detector.empty():
    print("Error loading cascade classifier!")

detections = face_detector.detectMultiScale(image_gray)

# %%
display(detections)
# Out:
# array([[147, 120,  59,  59],
#        [600, 122,  63,  63],
#        [851,  70,  74,  74],
#        [485, 228,  86,  86],
#        [121, 237,  70,  70]])

# %%
detections.shape
# Out:
# (5, 4)

# %%
x=147  # X - Co ordinates 
y=120  # Y- Co ordinates 
w=59   # Face Width
h=59   # Face Height 
# Draw the rectangle with co-ordinate specified above 
# (0,255,255) - This is RBG colour for rectangle 
# 1 is the thickness of rectangle 
cv2.rectangle(image_gray, (x, y), (x + w, y + h), (0,255,255), 3)
cv2.imshow('', image_gray)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
x=600  # X - Co ordinates 
y=122  # Y- Co ordinates 
w=63   # Face Width
h=63   # Face Height 
# Draw the rectangle with co-ordinate specified above 
# (0,255,255) - This is RBG colour for rectangle 
# 1 is the thickness of rectangle 
cv2.rectangle(image_gray, (x, y), (x + w, y + h), (0,255,255), 3)
cv2.imshow('', image_gray)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
x=851  # X - Co ordinates 
y=70  # Y- Co ordinates 
w=74   # Face Width
h=74   # Face Height 
# Draw the rectangle with co-ordinate specified above 
# (0,255,255) - This is RBG colour for rectangle 
# 1 is the thickness of rectangle 
cv2.rectangle(image_gray, (x, y), (x + w, y + h), (0,255,255), 3)
cv2.imshow('', image_gray)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
x=485  # X - Co ordinates 
y=228  # Y- Co ordinates 
w=86   # Face Width
h=86   # Face Height 
# Draw the rectangle with co-ordinate specified above 
# (0,255,255) - This is RBG colour for rectangle 
# 1 is the thickness of rectangle 
cv2.rectangle(image_gray, (x, y), (x + w, y + h), (0,255,255), 3)
cv2.imshow('', image_gray)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
x=121  # X - Co ordinates 
y=237  # Y- Co ordinates 
w=70   # Face Width
h=70   # Face Height 
# Draw the rectangle with co-ordinate specified above 
# (0,255,255) - This is RBG colour for rectangle 
# 1 is the thickness of rectangle 
cv2.rectangle(image_gray, (x, y), (x + w, y + h), (0,255,255), 3)
cv2.imshow('', image_gray)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
for (x, y, w, h) in detections:
  cv2.rectangle(image_gray, (x, y), (x + w, y + h), (0,255,255), 5)
cv2.imshow('', image_gray)
cv2.waitKey(5000)
plt.show()
cv2.destroyAllWindows()

# %%
for (x, y, w, h) in detections:
  cv2.rectangle(image, (x, y), (x + w, y + h), (0,100,100), 5)
cv2.imshow('', image)
cv2.waitKey(5000)
plt.show()
cv2.destroyAllWindows()

# %%
image2 = cv2.imread('C:\\Users\\skv96\\Downloads\\PRJ Face Detection-20240102T164837Z-001\\PRJ Face Detection\\Data Set\\people1.jpg')
image2
# Out:
# array([[[ 91, 103, 107],
#         [102, 114, 118],
#         [ 94, 106, 110],
#         ...,
#         [187, 192, 193],
#         [186, 191, 192],
#         [185, 190, 191]],
#
#        [[ 93, 105, 109],
#         [ 97, 109, 113],
#         [ 95, 110, 113],
#         ...,
#         [187, 192, 193],
#         [186, 191, 192],
#         [185, 190, 191]],
#
#        [[ 98, 110, 114],
#         [ 98, 110, 114],
#         [102, 117, 120],
#         ...,
#         [186, 191, 192],
#         [185, 190, 191],
#         [184, 189, 190]],
#
#        ...,
#
#        [[ 48,  43,  40],
#         [ 46,  41,  38],
#         [ 44,  39,  36],
#         ...,
#         [251, 248, 244],
#         [252, 247, 244],
#         [251, 246, 243]],
#
#        [[ 55,  49,  44],
#         [ 53,  47,  42],
#         [ 49,  42,  39],
#         ...,
#         [252, 247, 244],
#         [252, 247, 244],
#         [252, 247, 244]],
#
#        [[ 56,  50,  45],
#         [ 54,  48,  43],
#         [ 50,  44,  39],
# ...

# %%
image2 = cv2.resize(image2, (1000,800))
display(image2.shape)
# Out:
# (800, 1000, 3)

# %%
detections = face_detector.detectMultiScale(image2)
display (detections)
# Out:
# array([[144, 167,  66,  66],
#        [595, 165,  73,  73],
#        [845,  99,  89,  89],
#        [481, 311,  95,  95],
#        [112, 320,  86,  86],
#        [192, 531,  57,  57]])

# %%
for (x, y, w, h) in detections:
  cv2.rectangle(image2, (x, y), (x + w, y + h), (0,255,255), 5)
cv2.imshow('',image2)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %%
cv2.imshow('',image_gray)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %%
image3 = cv2.imread('C:\\Users\\skv96\\Downloads\\PRJ Face Detection-20240102T164837Z-001\\PRJ Face Detection\\Data Set\\people2.jpg')

detections = face_detector.detectMultiScale(image3, scaleFactor = 2.1)
display (detections)
# Out:
# array([[421,  29,  50,  50],
#        [167,  34,  50,  50],
#        [236,  44,  50,  50],
#        [320,  46,  50,  50],
#        [381,  55,  50,  50],
#        [599,  59,  50,  50],
#        [907,  63,  50,  50],
#        [479,  67,  50,  50],
#        [ 91,  81,  50,  50],
#        [659,  80,  50,  50],
#        [716,  99,  50,  50],
#        [825,  91,  50,  50]])

# %%
for (x, y, w, h) in detections:
    cv2.rectangle(image3, (x, y), (x + w, y + h), (0,255,0), 5)
cv2.imshow('',image3)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %%
cv2.imshow('',image3)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %%
image3 = cv2.imread('C:\\Users\\skv96\\Downloads\\PRJ Face Detection-20240102T164837Z-001\\PRJ Face Detection\\Data Set\\people2.jpg')
cv2.imshow('',image3)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %%
image_gray = cv2.cvtColor(image3, cv2.COLOR_BGR2GRAY)
cv2.imshow('',image_gray)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %%
detections = face_detector.detectMultiScale(image_gray, scaleFactor = 1.5,minNeighbors=6)
display (detections)
for (x, y, w, h) in detections:
    print(w, h)
    cv2.rectangle(image_gray, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image_gray)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# array([[380,  54,  54,  54]])
# 54 54

# %%
image  = cv2.imread("C:\\Users\\skv96\\Downloads\\PRJ Face Detection-20240102T164837Z-001\\PRJ Face Detection\\Data Set\\people2.jpg")
image_gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
detections = face_detector.detectMultiScale(image_gray, scaleFactor = 1.2,
                                            minNeighbors=7,minSize=(20,20), maxSize=(100,100))
display (detections)
for (x, y, w, h) in detections:
    print(w, h)
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# array([[424,  31,  47,  47],
#        [168,  35,  49,  49],
#        [321,  48,  47,  47],
#        [717, 100,  46,  46],
#        [600,  60,  49,  49],
#        [380,  54,  52,  52],
#        [906,  63,  51,  51],
#        [234,  46,  50,  50],
#        [662,  83,  44,  44],
#        [480,  70,  47,  47],
#        [ 91,  81,  51,  51],
#        [825,  91,  51,  51]])
# 47 47
# 49 49
# 47 47
# 46 46
# 49 49
# 52 52
# 51 51
# 50 50
# 44 44
# 47 47
# 51 51
# 51 51

# %%
eye_detector= cv2.CascadeClassifier('C:\\Users\\skv96\\Downloads\\PRJ Face Detection-20240102T164837Z-001\\PRJ Face Detection\\Cascades\\haarcascade_eye.xml')
display(eye_detector)
# Out:
# < cv2.CascadeClassifier 0000022CC9010110>

# %%
image = cv2.imread('C:\\Users\\skv96\\Downloads\\PRJ Face Detection-20240102T164837Z-001\\PRJ Face Detection\\Data Set\\people1.jpg')
display (image.shape)

image = cv2.resize(image, (1600,1000)) # Resize image
print(image.shape)
face_detections = face_detector.detectMultiScale(image, scaleFactor = 1.3, minSize = (30,30))
for (x, y, w, h) in face_detections:
  cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)

eye_detections = eye_detector.detectMultiScale(image, scaleFactor = 1.1, minNeighbors=10, maxSize=(60,60))

for (x, y, w, h) in eye_detections:
  print(w, h)
  cv2.rectangle(image, (x, y), (x + w, y + h), (0,0,255), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# (1280, 1920, 3)
# (1000, 1600, 3)
# 22 22
# 28 28
# 23 23
# 23 23
# 28 28
# 33 33
# 31 31
# 25 25
# 34 34

# %%
car_detector = cv2.CascadeClassifier('C:\\Users\\skv96\\Downloads\\PRJ Face Detection-20240102T164837Z-001\\PRJ Face Detection\\Cascades\\cars.xml')

display (car_detector)
# Out:
# < cv2.CascadeClassifier 0000022CC908B550>

# %%
image = cv2.imread('C:\\Users\\skv96\\Downloads\\PRJ Face Detection-20240102T164837Z-001\\PRJ Face Detection\\Data Set\\car.jpg')
display (image.shape)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# (286, 468, 3)

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = car_detector.detectMultiScale(image_gray, scaleFactor = 1.03, minNeighbors=8)                                      
for (x, y, w, h) in detections:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %%
clock_detector = cv2.CascadeClassifier('C:\\Users\\skv96\\Downloads\\PRJ Face Detection-20240102T164837Z-001\\PRJ Face Detection\\Cascades\\clocks.xml')
display (clock_detector)
# Out:
# < cv2.CascadeClassifier 0000022CC9010170>

# %%
image = cv2.imread('C:\\Users\\skv96\\Downloads\\PRJ Face Detection-20240102T164837Z-001\\PRJ Face Detection\\Data Set\\clock.jpg')
display (image.shape)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# (438, 450, 3)

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = clock_detector.detectMultiScale(image_gray, scaleFactor = 1.03, minNeighbors=1)                                      
for (x, y, w, h) in detections:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %%
full_detector  = cv2.CascadeClassifier('C:\\Users\\skv96\\Downloads\\PRJ Face Detection-20240102T164837Z-001\\PRJ Face Detection\\Cascades\\fullbody.xml')
display (full_detector)
# Out:
# < cv2.CascadeClassifier 0000022CC908B490>

# %%
image = cv2.imread('C:\\Users\\skv96\\Downloads\\PRJ Face Detection-20240102T164837Z-001\\PRJ Face Detection\\Data Set\\people3.jpg')
display (image.shape)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# (294, 626, 3)

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = full_detector.detectMultiScale(image_gray, scaleFactor = 1.05, minNeighbors=5,    minSize = (50,50)) 
for (x, y, w, h) in detections:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %%
import dlib

# %%
image = cv2.imread('C:\\Users\\skv96\\Downloads\\PRJ Face Detection-20240102T164837Z-001\\PRJ Face Detection\\Data Set\\people2.jpg')
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %%
face_detector_hog = dlib.get_frontal_face_detector()
detections = face_detector_hog(image, 1) # 1 – is the scale factor

# %%
display (len(detections))
display (detections)
# Out:
# 14
# rectangles[[(429, 38) (465, 74)], [(665, 90) (701, 126)], [(717, 103) (760, 146)], [(909, 70) (952, 113)], [(828, 98) (871, 142)], [(605, 70) (641, 106)], [(777, 62) (813, 98)], [(485, 78) (521, 114)], [(386, 60) (429, 103)], [(170, 41) (213, 84)], [(93, 89) (136, 132)], [(237, 50) (280, 94)], [(323, 50) (367, 94)], [(544, 65) (588, 108)]]

# %%
print(detections[0])
print(detections[0].left())
print(detections[0].top())
print(detections[0].right())
print(detections[0].bottom())
cv2.rectangle(image, (detections[0].left(), detections[0].top()), (detections[0].right(), detections[0].bottom()), (0, 255, 255), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# [(429, 38) (465, 74)]
# 429
# 38
# 465
# 74

# %%
for face in detections:
  l, t, r, b = face.left(), face.top(), face.right(), face.bottom()
  cv2.rectangle(image, (l, t), (r, b), (0, 255, 255), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %%
image = cv2.imread('C:\\Users\\skv96\\Downloads\\PRJ Face Detection-20240102T164837Z-001\\PRJ Face Detection\\Data Set\\people2.jpg')
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %%
cnn_detector = dlib.cnn_face_detection_model_v1('C:\\Users\\skv96\\Downloads\\PRJ Face Detection-20240102T164837Z-001\\PRJ Face Detection\\Weights\\mmod_human_face_detector.dat')
display (cnn_detector)

# %%
detections = cnn_detector(image, 1)
for face in detections:
  l, t, r, b, c = face.rect.left(), face.rect.top(), face.rect.right(), face.rect.bottom(), face.confidence
  print(c)
  cv2.rectangle(image, (l, t), (r, b), (255, 255, 0), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# 1.1087620258331299
# 1.0691196918487549
# 1.0658056735992432
# 1.0608831644058228
# 1.0396673679351807
# 1.0221548080444336
# 1.0099083185195923
# 0.9993432760238647
# 0.9952684640884399
# 0.9860985279083252
# 0.9773248434066772
# 0.8571624755859375
# 0.8045071363449097

# %%
image = cv2.imread('C:\\Users\\skv96\\Downloads\\PRJ Face Detection-20240102T164837Z-001\\PRJ Face Detection\\Data Set\\people3.jpg')
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
haarcascade_detector = cv2.CascadeClassifier('C:\\Users\\skv96\\Downloads\\PRJ Face Detection-20240102T164837Z-001\\PRJ Face Detection\\Cascades\\haarcascade_frontalface_default.xml')
detections = haarcascade_detector.detectMultiScale(image_gray, scaleFactor = 1.001, minNeighbors=5, minSize = (5,5))
for (x, y, w, h) in detections:
  cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %%
image = cv2.imread('C:\\Users\\skv96\\Downloads\\PRJ Face Detection-20240102T164837Z-001\\PRJ Face Detection\\Data Set\\people3.jpg')
face_detector_hog = dlib.get_frontal_face_detector()
detections = face_detector_hog(image, 4)
for face in detections:
    l, t, r, b = (face.left(), face.top(), face.right(), face.bottom())
    cv2.rectangle(image, (l, t), (r, b), (0, 255, 255), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
